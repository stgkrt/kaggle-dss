# %% [markdown]
# # check oof df

# %%
import os

import numpy as np
import pandas as pd
from pandarallel import pandarallel
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %%
output_dir = os.path.join("/kaggle", "working")
exp_name = "debug"
oof_df_path = os.path.join(output_dir, exp_name,"oof_df.parquet")
oof_df = pd.read_parquet(oof_df_path)

# %%
oof_df.columns
# Out:
# Index(['series_id', 'series_date_key', 'timestamp', 'date', 'time', 'step',
#        'anglez', 'enmo', 'event', 'event_onset', 'event_wakeup', 'class_pred',
#        'event_onset_pred', 'event_wakeup_pred', 'class_target',
#        'event_onset_target', 'event_wakeup_target'],
#       dtype='object')

# %%
oof_df.head()
# Out:
#             series_id          series_date_key           timestamp  \
# 1081800  1087d7b0ff2e  1087d7b0ff2e_2018-03-13 2018-03-13 13:15:00
# 1081801  1087d7b0ff2e  1087d7b0ff2e_2018-03-13 2018-03-13 13:15:05
# 1081802  1087d7b0ff2e  1087d7b0ff2e_2018-03-13 2018-03-13 13:15:10
# 1081803  1087d7b0ff2e  1087d7b0ff2e_2018-03-13 2018-03-13 13:15:15
# 1081804  1087d7b0ff2e  1087d7b0ff2e_2018-03-13 2018-03-13 13:15:20
#
#                date      time  step     anglez    enmo  event  event_onset  \
# 1081800  2018-03-13  13:15:00     0 -87.805298  0.0227    0.0            0
# 1081801  2018-03-13  13:15:05     1 -87.803802  0.0224    0.0            0
# 1081802  2018-03-13  13:15:10     2 -87.798897  0.0225    0.0            0
# 1081803  2018-03-13  13:15:15     3 -87.804802  0.0232    0.0            0
# 1081804  2018-03-13  13:15:20     4 -87.799896  0.0232    0.0            0
#
#          event_wakeup  class_pred  event_onset_pred  event_wakeup_pred  \
# 1081800             0    0.442921          0.624727           0.649372
# 1081801             0    0.423409          0.597300           0.656965
# 1081802             0    0.415746          0.588864           0.659249
# 1081803             0    0.392928          0.588110           0.659452
# 1081804             0    0.428373          0.587904           0.659508
#
#          class_target  event_onset_target  event_wakeup_target
# 1081800           0.0                 0.0                  0.0
# 1081801           0.0                 0.0                  0.0
# 1081802           0.0                 0.0                  0.0
# 1081803           0.0                 0.0                  0.0
# 1081804           0.0                 0.0                  0.0

# %%
# oof_df = oof_df[oof_df["series_date_key"]=="1087d7b0ff2e_2018-03-13"]
# print(len(oof_df))

# %%
def plot_inputs(df):
    plt.figure(figsize=(10, 5))
    plt.suptitle("inputs")
    plt.subplot(2, 1, 1)
    plt.plot(df["step"], df["anglez"])
    plt.xticks([])
    plt.subplot(2, 1, 2)
    plt.plot(df["step"], df["enmo"])
    plt.tight_layout()
    plt.show()

# %%
def plot_event_onset(df):
    plt.figure(figsize=(10, 5))
    plt.suptitle("event_onset")
    plt.subplot(3, 1, 1)
    plt.plot(df["step"], df["event_onset"], label="label")
    plt.xticks([])
    plt.subplot(3, 1, 2)
    plt.plot(df["step"], df["event_onset_target"], label="pred")
    plt.xticks([])
    plt.subplot(3, 1, 3)
    plt.plot(df["step"], df["event_onset_pred"], label="pred")
    plt.tight_layout()
    plt.show()

# %%
def plot_event_wakeup(df):
    plt.figure(figsize=(10, 5))
    plt.suptitle("event_wakeup")
    plt.subplot(3, 1, 1)
    plt.plot(df["step"], df["event_wakeup"], label="label")
    plt.xticks([])
    plt.subplot(3, 1, 2)
    plt.plot(df["step"], df["event_wakeup_target"], label="pred")
    plt.xticks([])
    plt.subplot(3, 1, 3)
    plt.plot(df["step"], df["event_wakeup_pred"], label="pred")
    plt.tight_layout()
    plt.show()

# %%
def plot_event_sleep(df):
    plt.figure(figsize=(10, 5))
    plt.suptitle("class")
    plt.subplot(2, 1, 1)
    plt.plot(df["step"], df["class_target"], label="label")
    plt.xticks([])
    plt.subplot(2, 1, 2)
    plt.plot(df["step"], df["class_pred"], label="pred")
    plt.tight_layout()
    plt.show()

# %%
oof_df["series_date_key"].unique()
# Out:
# array(['1087d7b0ff2e_2018-03-13', '1087d7b0ff2e_2018-03-14',
#        '1087d7b0ff2e_2018-03-15', '1087d7b0ff2e_2018-03-16',
#        '1087d7b0ff2e_2018-03-17', '1087d7b0ff2e_2018-03-18',
#        '1087d7b0ff2e_2018-03-19', '1087d7b0ff2e_2018-03-20',
#        '1087d7b0ff2e_2018-03-21', '1087d7b0ff2e_2018-03-22',
#        '1087d7b0ff2e_2018-03-23', '1087d7b0ff2e_2018-03-24',
#        '1087d7b0ff2e_2018-03-25', '1087d7b0ff2e_2018-03-26',
#        '1087d7b0ff2e_2018-03-27', '1087d7b0ff2e_2018-03-28',
#        '1087d7b0ff2e_2018-03-29', '1087d7b0ff2e_2018-03-30',
#        '1087d7b0ff2e_2018-03-31', '1087d7b0ff2e_2018-04-01',
#        '1087d7b0ff2e_2018-04-02', '1087d7b0ff2e_2018-04-03',
#        '1087d7b0ff2e_2018-04-04', '1087d7b0ff2e_2018-04-05',
#        '1087d7b0ff2e_2018-04-06', '72bbd1ac3edf_2017-09-19',
#        '72bbd1ac3edf_2017-09-20', '72bbd1ac3edf_2017-09-21',
#        '72bbd1ac3edf_2017-09-22', '72bbd1ac3edf_2017-09-23',
#        '72bbd1ac3edf_2017-09-24', '72bbd1ac3edf_2017-09-25',
#        '72bbd1ac3edf_2017-09-26', '72bbd1ac3edf_2017-09-27',
#        '72bbd1ac3edf_2017-09-28', '72bbd1ac3edf_2017-09-29',
#        '72bbd1ac3edf_2017-09-30', '72bbd1ac3edf_2017-10-01',
#        '72bbd1ac3edf_2017-10-02', '72bbd1ac3edf_2017-10-03',
#        '72bbd1ac3edf_2017-10-04', '72bbd1ac3edf_2017-10-05',
#        '72bbd1ac3edf_2017-10-06', '72bbd1ac3edf_2017-10-07',
#        '72bbd1ac3edf_2017-10-08', '72bbd1ac3edf_2017-10-09',
#        '72bbd1ac3edf_2017-10-10', '72bbd1ac3edf_2017-10-11',
#        '72bbd1ac3edf_2017-10-12', '76237b9406d5_2017-11-14',
#        '76237b9406d5_2017-11-15', '76237b9406d5_2017-11-16',
#        '76237b9406d5_2017-11-17', '76237b9406d5_2017-11-18',
#        '76237b9406d5_2017-11-19', '76237b9406d5_2017-11-20',
#        '76237b9406d5_2017-11-21', '76237b9406d5_2017-11-22',
#        '76237b9406d5_2017-11-23', '76237b9406d5_2017-11-24',
#        '76237b9406d5_2017-11-25', '76237b9406d5_2017-11-26',
#        '76237b9406d5_2017-11-27', '76237b9406d5_2017-11-28',
#        '76237b9406d5_2017-11-29', '76237b9406d5_2017-11-30',
#        '76237b9406d5_2017-12-01', '76237b9406d5_2017-12-02',
#        '76237b9406d5_2017-12-03', '76237b9406d5_2017-12-04',
#        '76237b9406d5_2017-12-05', '76237b9406d5_2017-12-06',
#        '76237b9406d5_2017-12-07', '76237b9406d5_2017-12-08',
#        'a9a2f7fac455_2017-10-27', 'a9a2f7fac455_2017-10-28',
#        'a9a2f7fac455_2017-10-29', 'a9a2f7fac455_2017-10-30',
#        'a9a2f7fac455_2017-10-31', 'a9a2f7fac455_2017-11-01',
#        'a9a2f7fac455_2017-11-02', 'a9a2f7fac455_2017-11-03',
#        'a9a2f7fac455_2017-11-04', 'a9a2f7fac455_2017-11-05',
#        'a9a2f7fac455_2017-11-06', 'a9a2f7fac455_2017-11-07',
#        'a9a2f7fac455_2017-11-08', 'a9a2f7fac455_2017-11-09',
#        'a9a2f7fac455_2017-11-10', 'a9a2f7fac455_2017-11-11',
#        'a9a2f7fac455_2017-11-12', 'a9a2f7fac455_2017-11-13',
#        'a9a2f7fac455_2017-11-14', 'a9a2f7fac455_2017-11-15',
#        'a9a2f7fac455_2017-11-16', 'a9a2f7fac455_2017-11-17',
#        'a9a2f7fac455_2017-11-18', 'a9a2f7fac455_2017-11-19',
#        'a9a2f7fac455_2017-11-20', 'a9a2f7fac455_2017-11-21',
#        'a9a2f7fac455_2017-11-22', 'a9a2f7fac455_2017-11-23',
#        'a9a2f7fac455_2017-11-24', 'a9a2f7fac455_2017-11-25',
#        'a9a2f7fac455_2017-11-26', 'a9a2f7fac455_2017-11-27',
#        'a9a2f7fac455_2017-11-28', 'a9a2f7fac455_2017-11-29',
#        'a9a2f7fac455_2017-11-30', 'a9a2f7fac455_2017-12-01',
#        'a9a2f7fac455_2017-12-02', 'a9a2f7fac455_2017-12-03',
#        'a9e5f5314bcb_2017-10-05', 'a9e5f5314bcb_2017-10-06',
#        'a9e5f5314bcb_2017-10-07', 'a9e5f5314bcb_2017-10-08',
#        'a9e5f5314bcb_2017-10-09', 'a9e5f5314bcb_2017-10-10',
#        'a9e5f5314bcb_2017-10-11', 'a9e5f5314bcb_2017-10-12',
#        'a9e5f5314bcb_2017-10-13', 'a9e5f5314bcb_2017-10-14',
#        'c535634d7dcd_2019-06-27', 'c535634d7dcd_2019-06-28',
#        'c535634d7dcd_2019-06-29', 'c535634d7dcd_2019-06-30',
#        'c535634d7dcd_2019-07-01', 'c535634d7dcd_2019-07-02',
#        'c535634d7dcd_2019-07-03', 'c535634d7dcd_2019-07-04',
#        'c535634d7dcd_2019-07-05', 'd150801f3145_2017-08-28',
#        'd150801f3145_2017-08-29', 'd150801f3145_2017-08-30',
#        'd150801f3145_2017-08-31', 'd150801f3145_2017-09-01',
#        'd150801f3145_2017-09-02', 'd150801f3145_2017-09-03',
#        'd150801f3145_2017-09-04', 'd150801f3145_2017-09-05',
#        'd150801f3145_2017-09-06', 'd150801f3145_2017-09-07',
#        'd150801f3145_2017-09-08', 'd150801f3145_2017-09-09',
#        'd150801f3145_2017-09-10', 'd150801f3145_2017-09-11',
#        'd150801f3145_2017-09-12', 'd150801f3145_2017-09-13',
#        'd150801f3145_2017-09-14', 'd150801f3145_2017-09-15',
#        'd150801f3145_2017-09-16', 'd150801f3145_2017-09-17',
#        'd150801f3145_2017-09-18', 'd150801f3145_2017-09-19',
#        'd150801f3145_2017-09-20', 'd25e479ecbb7_2017-11-27',
#        'd25e479ecbb7_2017-11-28', 'd25e479ecbb7_2017-11-29',
#        'd25e479ecbb7_2017-11-30', 'd25e479ecbb7_2017-12-01',
#        'd25e479ecbb7_2017-12-02', 'd25e479ecbb7_2017-12-03',
#        'd25e479ecbb7_2017-12-04', 'd25e479ecbb7_2017-12-05',
#        'd25e479ecbb7_2017-12-06', 'd25e479ecbb7_2017-12-07',
#        'd25e479ecbb7_2017-12-08', 'd25e479ecbb7_2017-12-09',
#        'd25e479ecbb7_2017-12-10', 'd25e479ecbb7_2017-12-11',
#        'd25e479ecbb7_2017-12-12', 'd25e479ecbb7_2017-12-13',
#        'd25e479ecbb7_2017-12-14', 'd25e479ecbb7_2017-12-15',
#        'd25e479ecbb7_2017-12-16', 'd25e479ecbb7_2017-12-17',
#        'd25e479ecbb7_2017-12-18'], dtype=object)

# %%
random_series_date_key = np.random.choice(oof_df["series_date_key"].unique(), 1, replace=False)
print(random_series_date_key)
for key in random_series_date_key:
    print(key)
    df = oof_df[oof_df["series_date_key"]==key]
    plot_inputs(df)
    plot_event_sleep(df)
    plot_event_onset(df)
    plot_event_wakeup(df)
    print("----------------------------------")
# Out:
# ['a9a2f7fac455_2017-10-27']
# a9a2f7fac455_2017-10-27
# ----------------------------------
