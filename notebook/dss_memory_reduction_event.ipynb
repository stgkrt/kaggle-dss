# %% [markdown]
# # Memory Reduction
# https://www.kaggle.com/code/andradaolteanu/zzz-good-night-sleep-with-80-memory-reduction/notebook

# %%
import os

import numpy as np
import pandas as pd
import cudf
import matplotlib.pyplot as plt

import gc
import torch

# %%
class CFG:
    input_dir = os.path.join("/kaggle", "input")
    output_dir = os.path.join("/kaggle", "working")
    competition_dir = os.path.join(input_dir, "child-mind-institute-detect-sleep-states")
    train_series = os.path.join(competition_dir, "train_series.parquet")
    train_event = os.path.join(competition_dir, "train_events.csv")
    test_series = os.path.join(competition_dir, "test_series.parquet")
    sample_sub = os.path.join(competition_dir, "sample_submission.csv")

# %% [markdown]
# # Event memory reduction

# %%
train_event = cudf.read_csv(CFG.train_event)

# %% [markdown]
# ## series_id map

# %%
train_id_map = cudf.DataFrame({"series_id": train_event.series_id.unique(),
                               "id_map": train_event.series_id.unique().index})
train_id_map.id_map = train_id_map.id_map.astype(np.uint16)
train_event = train_event.merge(right=train_id_map, on="series_id").drop(columns="series_id")

# %%
train_event.night = train_event.night.astype(np.uint16)
# event relabeled
train_event.event = train_event.event.replace({'onset':'1', 'wakeup':'2'}).astype(np.uint8)
# step
train_event.step = train_event.step.astype(np.uint32)
# timestamp
train_event.timestamp = cudf.to_datetime(train_event.timestamp, format='%Y-%m-%d %H:%M:%S')

# %%
train_map_path = os.path.join(CFG.input_dir, "comp_train_id_map.parquet")
train_event_path = os.path.join(CFG.input_dir, "comp_train_event.parquet")

train_id_map.to_parquet(train_map_path, index=False)
train_event.to_parquet(train_event_path, index=False)

# %% [markdown]
# # Series memory reduction

# %%
series = cudf.read_parquet(CFG.train_series)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /kaggle/notebook/dss-memory-reduction.ipynb セル 11 line 1
# ----> <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f686f6d652f7461726f2f70726f6a656374732f6b6167676c652d6473732f6b6167676c652d647373222c2273657474696e6773223a7b22686f7374223a227373683a2f2f7461726f333039302d6c6f63616c227d7d/kaggle/notebook/dss-memory-reduction.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> series = cudf.read_parquet(CFG.train_series)
#
# File /opt/conda/lib/python3.10/site-packages/nvtx/nvtx.py:101, in annotate.__call__.<locals>.inner(*args, **kwargs)
#      98 @wraps(func)
#      99 def inner(*args, **kwargs):
#     100     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101     result = func(*args, **kwargs)
#     102     libnvtx_pop_range(self.domain.handle)
#     103     return result
#
# File /opt/conda/lib/python3.10/site-packages/cudf/io/parquet.py:556, in read_parquet(filepath_or_buffer, engine, columns, storage_options, filters, row_groups, strings_to_categorical, use_pandas_metadata, use_python_file_object, categorical_partitions, open_file_options, bytes_per_thread, dataset_kwargs, *args, **kwargs)
#     549         warnings.warn(
#     550             "Parquet row-group filtering is only supported with "
#     551             "'engine=cudf'. Use pandas or pyarrow API directly "
#     552             "for full CPU-based filtering functionality."
#     553         )
#     555 # Convert parquet data to a cudf.DataFrame
# --> 556 df = _parquet_to_frame(
#     557     filepaths_or_buffers,
#     558     engine,
#     559     *args,
#     560     columns=columns,
#     561     row_groups=row_groups,
#     562     strings_to_categorical=strings_to_categorical,
#     563     use_pandas_metadata=use_pandas_metadata,
#     564     partition_keys=partition_keys,
#     565     partition_categories=partition_categories,
#     566     dataset_kwargs=dataset_kwargs,
#     567     **kwargs,
#     568 )
#     570 # Apply filters row-wise (if any are defined), and return
#     571 return _apply_post_filters(df, filters)
#
# File /opt/conda/lib/python3.10/site-packages/nvtx/nvtx.py:101, in annotate.__call__.<locals>.inner(*args, **kwargs)
#      98 @wraps(func)
#      99 def inner(*args, **kwargs):
#     100     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101     result = func(*args, **kwargs)
#     102     libnvtx_pop_range(self.domain.handle)
#     103     return result
#
# File /opt/conda/lib/python3.10/site-packages/cudf/io/parquet.py:694, in _parquet_to_frame(paths_or_buffers, row_groups, partition_keys, partition_categories, dataset_kwargs, *args, **kwargs)
#     680 @_cudf_nvtx_annotate
#     681 def _parquet_to_frame(
#     682     paths_or_buffers,
#    (...)
#     691     # If this is not a partitioned read, only need
#     692     # one call to `_read_parquet`
#     693     if not partition_keys:
# --> 694         return _read_parquet(
#     695             paths_or_buffers,
#     696             *args,
#     697             row_groups=row_groups,
#     698             **kwargs,
#     699         )
#     701     partition_meta = None
#     702     partitioning = (dataset_kwargs or {}).get("partitioning", None)
#
# File /opt/conda/lib/python3.10/site-packages/nvtx/nvtx.py:101, in annotate.__call__.<locals>.inner(*args, **kwargs)
#      98 @wraps(func)
#      99 def inner(*args, **kwargs):
#     100     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 101     result = func(*args, **kwargs)
#     102     libnvtx_pop_range(self.domain.handle)
#     103     return result
#
# File /opt/conda/lib/python3.10/site-packages/cudf/io/parquet.py:803, in _read_parquet(filepaths_or_buffers, engine, columns, row_groups, strings_to_categorical, use_pandas_metadata, *args, **kwargs)
#     798     if args:
#     799         raise ValueError(
#     800             "cudf engine doesn't support the "
#     801             f"following positional arguments: {list(args)}"
#     802         )
# --> 803     return libparquet.read_parquet(
#     804         filepaths_or_buffers,
#     805         columns=columns,
#     806         row_groups=row_groups,
#     807         strings_to_categorical=strings_to_categorical,
#     808         use_pandas_metadata=use_pandas_metadata,
#     809     )
#     810 else:
#     811     return cudf.DataFrame.from_arrow(
#     812         pq.ParquetDataset(filepaths_or_buffers).read_pandas(
#     813             columns=columns, *args, **kwargs
#     814         )
#     815     )
#
# File parquet.pyx:123, in cudf._lib.parquet.read_parquet()
#
# File parquet.pyx:182, in cudf._lib.parquet.read_parquet()
#
# MemoryError: std::bad_alloc: out_of_memory: CUDA error at: /opt/conda/include/rmm/mr/device/cuda_memory_resource.hpp

# %%
series = series.merge(right=train_id_map, on="series_id")\
            .drop(columns="series_id")\
            .reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /kaggle/notebook/dss-memory-reduction.ipynb セル 12 line 1
# ----> <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f686f6d652f7461726f2f70726f6a656374732f6b6167676c652d6473732f6b6167676c652d647373222c2273657474696e6773223a7b22686f7374223a227373683a2f2f7461726f333039302d6c6f63616c227d7d/kaggle/notebook/dss-memory-reduction.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> series = series.merge(right=train_id_map, on="series_id")\
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f686f6d652f7461726f2f70726f6a656374732f6b6167676c652d6473732f6b6167676c652d647373222c2273657474696e6773223a7b22686f7374223a227373683a2f2f7461726f333039302d6c6f63616c227d7d/kaggle/notebook/dss-memory-reduction.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>             .drop(columns="series_id")\
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f686f6d652f7461726f2f70726f6a656374732f6b6167676c652d6473732f6b6167676c652d647373222c2273657474696e6773223a7b22686f7374223a227373683a2f2f7461726f333039302d6c6f63616c227d7d/kaggle/notebook/dss-memory-reduction.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>             .reset_index(drop=True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
#   10103         suffixes=suffixes,
#   10104         copy=copy,
#   10105         indicator=indicator,
#   10106         validate=validate,
#   10107     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/merge.py:645, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     628 def __init__(
#     629     self,
#     630     left: DataFrame | Series,
#    (...)
#     642     validate: str | None = None,
#     643 ) -> None:
#     644     _left = _validate_operand(left)
# --> 645     _right = _validate_operand(right)
#     646     self.left = self.orig_left = _left
#     647     self.right = self.orig_right = _right
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/merge.py:2426, in _validate_operand(obj)
#    2424         return obj.to_frame()
#    2425 else:
# -> 2426     raise TypeError(
#    2427         f"Can only merge Series or DataFrame objects, a {type(obj)} was passed"
#    2428     )
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'cudf.core.dataframe.DataFrame'> was passed

# %%
series.step = series.step.astype(np.uint32)

# %% [markdown]
# ## datetime encodeing

# %%
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)

# Local Time converter
def to_date_time(x):
    import pandas as pd
    return pd.to_datetime(x, format='%Y-%m-%d %H:%M:%S') # utc=True

def to_localize(t):
    import pandas as pd
    return t.tz_localize(None)

series["timestamp"] = series.timestamp.parallel_apply(to_date_time).parallel_apply(to_localize)

# %%
series_path = os.path.join(CFG.input_dir, "comp_train_series.parquet")
series.to_parquet(series_path, index=False)
